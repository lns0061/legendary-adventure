# %% [markdown]
# <a href="https://colab.research.google.com/github/lns0061/legendary-adventure/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
r1=910
r2=3000
r3=1500
r4=110
w=2*np.pi*10**(4)
l=6.7*10**(-3)
c=10**(-8)
modulz1 = (r1+r4+((r2**(2)*r3)+w**(2)*l**(2)*r2+r2*r3**(2))/((r2+r3)**(2)+(w*l)**(2)))**2
modulz2= (-1/(w*c)+(w*l*r2**(2))/((r2+r3)**(2)+(w*l)**(2)))**2
 #(-1/(w*c)+(w*l*r2**(2))/((r2+r3)**(2)+(w*l)**(2)))**2)
print(np.format_float_scientific((modulz2+modulz1)**(1/2),precision=3))
# Out:
# 2.475e+03

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0, 1*10**-3, 1*10**-6)
l=6.7*10**(-3)
c=10**(-8)
w=2*np.pi*10**(4)
ur1=1.1*np.sin(w*t)
uc=1.9*np.sin(w*t-np.pi)
ur4=0.132*np.sin(w*t)
ur2=1.2*np.sin(w*t)
ur3=1.2*np.sin(w*t)
ul=0.168*np.sin(w*t+np.pi)
Ir4=ur1/110
Ir2=ur1/3000
Ic=uc/(1/(w*c))
Il=ul/(w*l)

plt.plot(t, ur1, color='red', label='ur1')
##plt.plot(t, uc, color='r', label='ur1')
#plt.plot(t, ur4, color='red', label='ur1')
#plt.plot(t, ur2, color='red', label='ur1')
#plt.plot(t, ur3, color='red', label='ur1')
#plt.plot(t, ul, color='red', label='ur1')
plt.title('Напряжение на r1')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, uc, color='r', label='ur1')
plt.title('Напряжение на c')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, ur4, color='r', label='ur1')
plt.title('Напряжение на r4')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, ur2, color='r', label='ur1')
plt.title('Напряжение на r2')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, ur3, color='r', label='ur1')
plt.title('Напряжение на r3')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, ul, color='r', label='ur1')
plt.title('Напряжение на l')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, Ir2, color='r', label='ur1')
plt.title('Ток на r2')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, Ic, color='r', label='ur1')
plt.title('Ток на c')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, Il, color='r', label='ur1')
plt.title('Ток на l')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
plt.plot(t, Ir4, color='r', label='ur1')
plt.title('Ток на r4')
plt.xlabel('t')
plt.ylabel('u')
plt.grid(True)
plt.show()
